# %% [markdown]
# # Run HTML ML Business Dashboard Generator
#
# This notebook **only does one job**:
#
# - Run `generate_html_dashboard.py`
# - Create / refresh `dashboard/olist_ml_business_dashboard.html`
#
# Make sure you are using the **`eltn` conda environment** before running.

# %%
from pathlib import Path

# 🔧 Adjust this if your repo path changes
BASE_DIR = Path('/home/pingh/Brazilian-E-Commerce-Public-Dataset-by-Olist')
DASHBOARD_DIR = BASE_DIR / 'dashboard'
SCRIPT_PATH = DASHBOARD_DIR / 'generate_html_dashboard.py'
HTML_PATH = DASHBOARD_DIR / 'olist_ml_business_dashboard.html'

print('Base dir     :', BASE_DIR)
print('Script path  :', SCRIPT_PATH)
print('HTML output  :', HTML_PATH)
print('\nScript exists? ', SCRIPT_PATH.exists())
print('Old HTML exists?', HTML_PATH.exists())

# %% [markdown]
# ## Run the HTML Dashboard Generator
#
# The cell below executes `generate_html_dashboard.py` using IPython's `%run` magic.
#
# If it runs successfully, you should see a new/updated file:
#
# `dashboard/olist_ml_business_dashboard.html`

# %%
print('🚀 Generating HTML dashboard...')
# %run /home/pingh/Brazilian-E-Commerce-Public-Dataset-by-Olist/dashboard/generate_html_dashboard.py
print('✅ Dashboard generation script finished.')

# %% [markdown]
# ## Verify Output
#
# This checks that the HTML file was created/updated.

# %%
from pathlib import Path

HTML_PATH = Path('/home/pingh/Brazilian-E-Commerce-Public-Dataset-by-Olist/dashboard/olist_ml_business_dashboard.html')
print('HTML file exists:', HTML_PATH.exists())
if HTML_PATH.exists():
    print('Full path:', HTML_PATH)
    print('You can open it via explorer.exe or from VS Code → right-click → Open in Default Browser.')
